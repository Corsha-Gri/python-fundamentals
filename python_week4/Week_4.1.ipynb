# %%
grade = 85
if grade >= 60:
    print('You passed!')
    print('Congratulations!')
print('Grade check complete')
# If grade is 85
# Out:
# You passed!
# Congratulations!
# Grade check complete

# %%
grade = 50
if grade >= 60:
    print('You passed!')
    print('Congratulations!')
print('Grade check complete')
#If grade was 50
# Out:
# Grade check complete

# %%
5 == 5
# Out:
# True

# %%
5!= 3
# Out:
# True

# %%
10 > 20
# Out:
# False

# %%
20 > 10
# Out:
# True

# %%
age = 25

# %%
score = 95

# %%
name = 'Alice'

# %%
print(age >= 18)
# Out:
# True

# %%
print(score == 100)
# Out:
# False

# %%
print(name == 'Bob')
# Out:
# False

# %%
if score >= 90:
    print('A garde!')
# Out:
# A garde!

# %%
if age < 21:
    print('Under 21')

# %%
grade = 75
if grade >= 60:
    print('PASSED')
    status = 'pass'
else:
    print('FAILED')
    status = 'fail'
print(f'Status: {status}')
# Out:
# PASSED
# Status: pass

# %%
grade = 45
if grade >= 60:
    print('PASSED')
    status = 'pass'
else:
    print('FAILED')
    status = 'fail'
print(f'Status: {status}')
# Out:
# FAILED
# Status: fail

# %%
score = 87
if score >= 90:
    letter = 'A'
elif score >= 80:
    letter = 'B'
elif score >= 70:
    letter = 'C'
elif score >= 60:
    letter = 'D'
else:
    letter = 'F'
print(f'Score {score} = Grade {letter}')
# Out:
# Score 87 = Grade B

# %%
if score >= 60:
    letter = 'D'
elif score >= 90:
    letter = 'A'
#Wrong Order

# %%
if score >= 90:
    letter = 'A'
elif score >= 60:
    letter = 'D'
#Correct order

# %%
age = 25
has_license = True
if age >= 21 and has_license:
     print('You can rent car')
else:
    print('Cannot rent car')
# Out:
# You can rent car

# %%
age = 18
has_license = True
if age >= 21 and has_license:
     print('You can rent car')
else:
    print('Cannot rent car')
# Out:
# Cannot rent car

# %%
is_weekend = True
is_holiday = False
if is_weekend or is_holiday:
    print('Sleep in!')
else:
    print('Set alarm')
# Out:
# Sleep in!

# %%
is_weekend = False
is_holiday = False
if is_weekend or is_holiday:
    print('Sleep in!')
else:
    print('Set alarm')
# Out:
# Set alarm

# %%
is_raining = False
if not is_raining:
    print('Go for a walk!')
else:
    print('Stay inside')
# Out:
# Go for a walk!

# %%
is_member = True
if not is_member:
    print('Please sign up')

# %%
is_raining = True
if not is_raining:
    print('Go for a walk!')
else:
    print('Stay inside')
# Out:
# Stay inside

# %%
is_member = False
if not is_member:
    print('Please sign up')
# Out:
# Please sign up

# %%
is_raining = False
if not is_raining:
    print('Go for a walk!')
else:
    print('Stay inside')
# Out:
# Go for a walk!

# %%
is_member = True
if not is_member:
    print('Please sign up')

# %%
is_raining = True
if not is_raining:
    print('Go for a walk!')
else:
    print('Stay inside')
# Out:
# Stay inside

# %%
gps = 3.8
test_score = 1350
has_recommendation = True
if (gps >= 3.5 and test_score >= 1300) or has_recommendation:
    print('ACCEPTED!')
else:
    print('Not accepted')
# Out:
# ACCEPTED!

# %%
data = [1, 2, 3]
if len(data) > 0:
    print('Has data')
# Out:
# Has data

# %%
if data:
    print('Has data')
# Out:
# Has data

# %%
empty = []
if not empty:
    print('List is empty')
# Out:
# List is empty

# %%
name = 'Alice'
if name:
    print(f'Hello, {name}')
# Out:
# Hello, Alice

# %%
score = 85
status = 'PASS' if score >= 60 else 'FAIL'
print(status)
# Out:
# PASS

# %%
age = 25
category = 'adult' if age >= 18 else 'minor'
print(status)
# Out:
# PASS

# %%
num = 7
parity = 'evem' if num % 2 == 0 else 'odd'
print(status)
# Out:
# PASS

# %%
a, b = 10, 15
max_value = a if a > b else b
print(status)
# Out:
# PASS
