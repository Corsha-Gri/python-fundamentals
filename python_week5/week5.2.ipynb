# %%
#students with detailed info
students = {
    'Alice': {
        'age': 20,
        'major': 'CS',
        'gpa': 3.8
    },
    'Bob': {
        'age': 21,
        'major': 'Math',
        'gpa': 3.6
    }
}

# %%
#access nested data
print(students['Alice']) #whole dict
# Out:
# {'age': 20, 'major': 'CS', 'gpa': 3.8}

# %%
print(students['Alice']['major']) #specific value
# Out:
# CS

# %%
print(students['Alice']['gpa'])
# Out:
# 3.8

# %%
company = {
    'engineering': {
        'employees': 50,
        'manager': 'Alice',
        'budget': 5000000
    },
    'marketing': {
        'employees': 20,
        'manager': 'Bob',
        'budegt': 2000000
    }
}

# %%
#access department info
eng_manager = company['engineering']['manager']
print(eng_manager)
# Out:
# Alice

# %%
#calculate total employees
total = company['engineering']['employees'] +  company['marketing']['employees']
print(f'Total employees: {total}')
# Out:
# Total employees: 70

# %%
students = {
    'Alice': {'age': 20, 'gpa': 3.8}
}

# %%
#add new student (outer value)
students['Bob'] = {'age': 21, 'gpa': 3.6}

# %%
#add field to existing student (inner level)
students['Alice']['major'] = 'CS'

# %%
#updated nested value
students['Alice']['gpa'] = 3.9

# %%
print(students['Alice'])
# Out:
# {'age': 20, 'gpa': 3.9, 'major': 'CS'}

# %%
#build up complex structures piece by piece

# %%
#grade book with multiple students
gradebook = {
    'Alice': {'math': 95, 'english': 92},
    'Bob': {'math': 87, 'english':90},
    'Carol': {'math': 92, 'english': 88}
}

# %%
#calculate average for each student
for name, grades in gradebook.items():
    total = sum(grades.values())
    avg = total / len(grades)
    print(f'{name}: {avg:.1f}')
# Out:
# Alice: 93.5
# Bob: 88.5
# Carol: 90.0

# %%
import json

# %%
#python dictionary
person = {
    'name': 'Alice',
    'age': 25,
    'city': 'Boston',
    'skills': ['Python', 'ML', 'Data Science']
}

# %%
#convert to json string
json_string = json.dumps(person)
print(json_string)
# Out:
# {"name": "Alice", "age": 25, "city": "Boston", "skills": ["Python", "ML", "Data Science"]}

# %%
#pretty print(indented)
json_pretty = json.dumps(person, indent=2)
print(json_pretty)
# Out:
# {
#   "name": "Alice",
#   "age": 25,
#   "city": "Boston",
#   "skills": [
#     "Python",
#     "ML",
#     "Data Science"
#   ]
# }

# %%
import json

# %%
#json string (from API, file, etc.)
json_data = '{"name": "Bob", "age": 30, "city": "NYC"}'

# %%
#convert to python dict
person = json.loads(json_data)
print(person)
# Out:
# {'name': 'Bob', 'age': 30, 'city': 'NYC'}

# %%
#now use like normal python dict
print(person['name'])
# Out:
# Bob

# %%
person['age']
# Out:
# 30

# %%
import json
#coonfiguration data

# %%
config = {
    'modle_type': 'neural_network',
    'learning_rate': 0.001,
    'epochs': 100,
    'layers': [128, 64, 32]
}

# %%
#write to file
with open('config.json', 'w') as file:
    json.dump(config, file, indent=2)

# %%
#creates config.json file:
print(json.dump)
# Out:
# <function dump at 0x104e2dbc0>

# %%
import json

# %%
#read config file
with open('config.json', 'r') as file:
    config = json.load(file)

# %%
#use as normal python dict
print(f"Model: {config['modle_type']}")
print(f"Learninig rate: {config['learning_rate']}")
# Out:
# Model: neural_network
# Learninig rate: 0.001

# %%
#access nested data
layers = config['layers']
print(f'Network layers: {layers}')
# Out:
# Network layers: [128, 64, 32]

# %%
#Modify and save back
config['epochs'] = 150
with open('config.json', 'w') as file:
    json.dump(config, file, indent=2)
