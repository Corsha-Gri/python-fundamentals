# %%
empty_list = []

# %%
ages = [25, 32, 28, 45, 19]

# %%
#list of strings
names = ['Alice', 'Bob', 'Carol', 'David']

# %%
#list of mixed types
person = ['Alice', 25, 'Engineer', True]

# %%
 print(ages)
# Out:
# [25, 32, 28, 45, 19]

# %%
print(names)
# Out:
# ['Alice', 'Bob', 'Carol', 'David']
