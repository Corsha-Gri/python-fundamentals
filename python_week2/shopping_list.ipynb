# %%
food = ['apples', 'bread', 'milk']

# %%
food.append('eggs')

# %%
print(food)
# Out:
# ['apples', 'bread', 'milk', 'eggs']

# %%
food.append('cheese')

# %%
print(food)
# Out:
# ['apples', 'bread', 'milk', 'eggs', 'cheese']

# %%
food.remove('bread')

# %%
print(food)
# Out:
# ['apples', 'milk', 'eggs', 'cheese']

# %%
food.insert(0, 'butter')

# %%
print(food)
# Out:
# ['butter', 'apples', 'milk', 'eggs', 'cheese']

# %%
count = len(food)

# %%
print(f'number of food:{count}')
# Out:
# number of food:5
