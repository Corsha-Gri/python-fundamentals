# %%
name = 'Corsha Griggs'

# %%
age = 28

# %%
previous_career = 'Electronics Team Member'

# %%
want_ml = True

# %%
print(name)
# Out:
# Corsha Griggs

# %%
print(age)
# Out:
# 28

# %%
print(previous_career)
# Out:
# Electronics Team Member

# %%
rent = 1500

# %%
food = 200

# %%
transport = 150

# %%
entertainment = 200

# %%
total_expenses = rent + food + transport + entertainment

# %%
print('Monthly expenses:', total_expenses)
# Out:
# Monthly expenses: 2050
