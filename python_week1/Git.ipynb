# %%
mkdir pyhton_practice
# Out:
# mkdir: pyhton_practice: File exists

# %%
cd pyhton_practice
# Out:
# /Users/shayarkibra/pyhton_practice

# %%
pwd
# Out:
# '/Users/shayarkibra/pyhton_practice'

# %%
# !git config --global user.name "Corsha Griggs"

# %%
# !git config --global user.email "corshagriggs2019@gmail.com"

# %%
mkdir python_practcie
# Out:
# mkdir: python_practcie: File exists

# %%
cd python_practice
# Out:
# [Errno 2] No such file or directory: 'python_practice'
# /Users/shayarkibra/pyhton_practice

# %%
pwd
# Out:
# '/Users/shayarkibra/pyhton_practice'

# %%
git init
# Out:
#   Cell In[9], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
