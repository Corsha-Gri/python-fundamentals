# %%
name = 'Alice'

# %%
job = 'Data Analyst'

# %%
message = "It's Monday!"

# %%
sentence = "She said, 'Hello'"

# %%
paragraph = '''This is a longer piece of text that spans multiple lines. Useful for descriptions!'''

# %%
print(name)
# Out:
# Alice

# %%
print(job)
# Out:
# Data Analyst

# %%
print(message)
# Out:
# It's Monday!

# %%
print(sentence)
# Out:
# She said, 'Hello'

# %%
print(paragraph)
# Out:
# This is a longer piece of text that spans multiple lines. Useful for descriptions!

# %%
name = "Alice's!"

# %%
print(name)
# Out:
# Alice's!

# %%
word = "pyhton"

# %%
print(word[0])
# Out:
# p

# %%
print(word[1])
# Out:
# y

# %%
print(word[5])
# Out:
# n

# %%
print(word[-1])
# Out:
# n

# %%
print(word[-2])
# Out:
# o

# %%
word[0:6]
# Out:
# 'pyhton'

# %%
text = "Hello World"

# %%
print(text[0:5])
# Out:
# Hello

# %%
print(text[6:])
# Out:
# World

# %%
print(text[:5])
# Out:
# Hello

# %%
print(text[-5:])
# Out:
# World

# %%
email = "sarah.johnson@techcompany.com"

# %%
at_position = email.index('@')

# %%
username = email[:at_position]

# %%
print(username)
# Out:
# sarah.johnson

# %%
domain = email[at_position+1:]

# %%
print(domain)
# Out:
# techcompany.com

# %%
name = " sarah johnson "

# %%
clean = name.strip()

# %%
print(clean)
# Out:
# sarah johnson

# %%
upper = clean.upper()

# %%
print(upper)
# Out:
# SARAH JOHNSON

# %%
title = clean.title()

# %%
print(title)
# Out:
# Sarah Johnson

# %%
new = clean.replace('sarah', 'Sarah')

# %%
print(new)
# Out:
# Sarah johnson

# %%
raw_data = [
    ' JOHN  SMITH ',
    ' alice  JOHNSON',
    'BOB  jones'
]

# %%
clean_data = []

for name in raw_data:
    clean = " ".join(name.split()).title()
    clean_data.append(clean)

print(clean_data)
# Out:
# ['John Smith', 'Alice Johnson', 'Bob Jones']

# %%
name = "Sarah"

# %%
age = 32

# %% [markdown]
# message = f'My name is {Corsha} and I am {27}

# %% [raw]
# score = 87

# %%
print(f'You scored {87}% which is {87/100:.2f}')
# Out:
# You scored 87% which is 0.87

# %%
epoch = 1

# %%
total_epochs = 100

# %%
loss = 0.456

# %%
accuracy = 0.892

# %%
print(f'Epoch {epoch}/{total_epochs}:')
# Out:
# Epoch 1/100:

# %%
print(f'  Loss: {loss:.3f}')
# Out:
#   Loss: 0.456

# %%
print(f'  Accuracy: {accuracy:.1%}')
# Out:
#   Accuracy: 89.2%

# %%
sentence = 'I love learning Pyhton for ML'

# %%
words = sentence.split()

# %%
print(words)
# Out:
# ['I', 'love', 'learning', 'Pyhton', 'for', 'ML']

# %%
word_count = len(words)

# %%
print(f'Word count: {word_count}')
# Out:
# Word count: 6

# %%
rejoined = ' '.join(words)

# %%
print(rejoined)
# Out:
# I love learning Pyhton for ML

# %%
filename = 'model_data.csv'

# %%
if 'data' in filename:
    print('This is a CSV file!')
# Out:
# This is a CSV file!

# %%
if filename.startswith('model'):
    print('This is a model file')
# Out:
# This is a model file

# %%
git status
