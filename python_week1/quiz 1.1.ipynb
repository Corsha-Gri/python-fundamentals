# %%
3**2
# Out:
# 9

# %%
(10//3)
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
(5+3*2)
# Out:
# 11

# %%
text = 'pyhton'

# %%
print(text[0:4])
# Out:
# pyht

# %%
word = 'Hello'

# %%
print(word[0])
# Out:
# H

# %%
'hello'.upper()
# Out:
# 'HELLO'

# %%
'Python'[-1]
# Out:
# 'n'

# %%
' hello '.strip()
# Out:
# 'hello'
