# %%
range(5)
# Out:
# range(0, 5)

# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(3,8):
              print(i)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
enumerate(['a', 'b', 'c'])

# %%
for i in range(2, 10, 3):
    print(i)
# Out:
# 2
# 5
# 8

# %%
total = 0

# %%
for i in range(1, 4):
    total += i

# %%
print(total)
# Out:
# 6

# %%
result = []

# %%
for i in range(3):
    result.append(i*2)

# %%
print(result)
# Out:
# [0, 2, 4]
