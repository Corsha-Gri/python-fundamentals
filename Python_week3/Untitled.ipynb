# %%
age = -1
while age < 0 or age > 120:
    age = int(input('Enter your age (0-120): '))
    if age < 0 or age > 120:
        print('Invalid! Try again.')
print(f'Valid age: {age}')
# Out:
# Enter your age (0-120):  230
# Invalid! Try again.
# Enter your age (0-120):  20
# Valid age: 20

# %%
for num in range(1, 1000):
    if num % 7 == 0 and num % 11 == 0:
        print(f'Found it: {num}')
        break
# Out:
# Found it: 77

# %%
numbers = [5, -3, 8, -1, 12, -7, 15, 0, 20]
for num in numbers:
    if num <= 0:
        continue
    squared = num ** 2
    print(f'{num} squared = {squared}')
# Out:
# 5 squared = 25
# 8 squared = 64
# 12 squared = 144
# 15 squared = 225
# 20 squared = 400
