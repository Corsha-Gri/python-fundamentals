# %%
for i in range(2): 
    for j in range(2):
        print(i * j)
# Out:
# 0
# 0
# 0
# 1

# %%
zip([1,2],['a','b'])

# %%
x = 5
while x > 0:
    x -= 1
print(x)
# Out:
# 0

# %%
matrix = [[1,2],[3,4]]
count = 0

# %%
for row in matrix:
    for val in row:
        count += 1
    print(matrix)
# Out:
# [[1, 2], [3, 4]]
# [[1, 2], [3, 4]]
